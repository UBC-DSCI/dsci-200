# %% [markdown]
# # Case Study II: Missing values, Outliers, and Simulation Studies
#
# - Name:
# - Student ID:
#
# This blank notebook is provided for you to use to answer questions from [Case Study 2](https://ubc-dsci.github.io/dsci-200/case-studies/case-study-2.html).
